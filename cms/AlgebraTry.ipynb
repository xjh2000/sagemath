# %%
from sage.all import *

# %%
x, y = var("x y")
z = sin(x) + cos(y)
z.function(x, y)
# Out:
# (x, y) |--> cos(y) + sin(x)

# %%
# expand, collect
z = (x + y) * (x + 1) ^ 2
e = z.expand().collect(x)
f = e.factor_list()
f
# Out:
# [(x + y, 1), (x + 1, 2)]

# %%
plot(sinh(x), (x, -5, 5), color="red", legend_label="sinh(x)")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f = cos(x) ^3 
print(f.reduce_trig())
# Out:
# 1/4*cos(3*x) + 3/4*cos(x)

# %%
z, phi = var('z, phi')
eq = z**2 - 2/cos(phi)*z + 5/cos(phi)**2 - 4 == 0
latex(solve(eq, z))
# Out:
# \left[z = -\frac{2 \, \sqrt{\cos\left(\phi\right)^{2} - 1} - 1}{\cos\left(\phi\right)}, z = \frac{2 \, \sqrt{\cos\left(\phi\right)^{2} - 1} + 1}{\cos\left(\phi\right)}\right]

# %% [markdown]
# $$z^{2} - \frac{2 \, z}{\cos\left(\phi\right)} + \frac{5}{\cos\left(\phi\right)^{2}} - 4 = 0 \\
# \left[z = -\frac{2 \, \sqrt{\cos\left(\phi\right)^{2} - 1} - 1}{\cos\left(\phi\right)}, z = \frac{2 \, \sqrt{\cos\left(\phi\right)^{2} - 1} + 1}{\cos\left(\phi\right)}\right]
# $$

# %%
n, k, p = var("n,k,p")
sum(k^4, k, 1, n)
# Out:
# 1/5*n^5 + 1/2*n^4 + 1/3*n^3 - 1/30*n

# %%
u = n ^ 100 / 100 ^ n
plot(u, n, 1, 50)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f = sin(x) - x
taylor(f, x, 0, 5)
# Out:
# 1/120*x^5 - 1/6*x^3

# %%
f = 1 / 2 * ln(x ^ 2 + y ^ 2)
plot3d(-f, (x, -5, 5), (y, -5, 5))
# Out:
# Graphics3d Object

# %%
A = matrix(QQ, [[2,4,3],[-4,-6,-3],[3,3,1]])
A.characteristic_polynomial()
# Out:
# x^3 + 3*x^2 - 4

# %%
A = matrix(QQ, [[1,-1/2],[-1/2,-1]])
A.minimal_polynomial().factor()
# Out:
# x^2 - 5/4
